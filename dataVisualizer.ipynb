# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
raw = pd.read_csv('Trading_Project_Data.csv', index_col = 0, parse_dates = True, header=1)

names = ['AAPL', 'MSFT', 'GOOGL', 'NVDA', 'TSLA', 'JNJ', 'PFE', 'UNH', 'XOM', 'CVX', 'JPM', 'GS', 'AMZN', 'WMT', 'KO', 'NKE', 'BA', 'CAT', 'SOFI']
# Out:
# /var/folders/2j/h6y_zlpd5sq1fhr8v9460g600000gn/T/ipykernel_60469/2447784492.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   raw = pd.read_csv('Trading_Project_Data.csv', index_col = 0, parse_dates = True, header=1)

# %%
prices = raw[names]
pd.plotting.scatter_matrix(prices, diagonal = 'hist', hist_kwds = {'bins': 20}, figsize=(15,15))
# Out:
# array([[<Axes: xlabel='AAPL', ylabel='AAPL'>,
#         <Axes: xlabel='MSFT', ylabel='AAPL'>,
#         <Axes: xlabel='GOOGL', ylabel='AAPL'>,
#         <Axes: xlabel='NVDA', ylabel='AAPL'>,
#         <Axes: xlabel='TSLA', ylabel='AAPL'>,
#         <Axes: xlabel='JNJ', ylabel='AAPL'>,
#         <Axes: xlabel='PFE', ylabel='AAPL'>,
#         <Axes: xlabel='UNH', ylabel='AAPL'>,
#         <Axes: xlabel='XOM', ylabel='AAPL'>,
#         <Axes: xlabel='CVX', ylabel='AAPL'>,
#         <Axes: xlabel='JPM', ylabel='AAPL'>,
#         <Axes: xlabel='GS', ylabel='AAPL'>,
#         <Axes: xlabel='AMZN', ylabel='AAPL'>,
#         <Axes: xlabel='WMT', ylabel='AAPL'>,
#         <Axes: xlabel='KO', ylabel='AAPL'>,
#         <Axes: xlabel='NKE', ylabel='AAPL'>,
#         <Axes: xlabel='BA', ylabel='AAPL'>,
#         <Axes: xlabel='CAT', ylabel='AAPL'>,
#         <Axes: xlabel='SOFI', ylabel='AAPL'>],
#        [<Axes: xlabel='AAPL', ylabel='MSFT'>,
#         <Axes: xlabel='MSFT', ylabel='MSFT'>,
# ...

# %%
prices['JPM'].corr(prices['GS'])
# Out:
# np.float64(0.9769519492744027)

# %% [markdown]
# We made
